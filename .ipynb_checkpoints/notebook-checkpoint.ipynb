# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/newfo/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Load dataset

# %%
dataset_path = "./dataset1/merged_dataset.csv"
df = pd.read_csv(dataset_path)
df.head()
