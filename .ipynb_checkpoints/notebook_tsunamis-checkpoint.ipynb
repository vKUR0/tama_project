# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import contextily as cx
import folium
from folium.plugins import HeatMap

# %% [markdown]
# # Load dataset

# %%
dataset_path = "./tsunamis-2026-05-25_16-23-01_+0900.csv"
df = pd.read_csv(dataset_path)
print(df.shape)
df.tail()
# Out:
# (57, 46)
#                      Search Parameters    Year    Mo    Dy    Hr    Mn   Sec  \
# 0   ["Year >= 2000","Country = JAPAN"]     NaN   NaN   NaN   NaN   NaN   NaN
# 1                                  NaN  2000.0   7.0   1.0   7.0   1.0  55.5
# 2                                  NaN  2000.0   7.0  15.0   1.0  30.0  30.5
# 3                                  NaN  2000.0   7.0  30.0  12.0  25.0  45.5
# 4                                  NaN  2002.0   3.0  26.0   3.0  45.0  48.7
# 5                                  NaN  2003.0   9.0  25.0  19.0  50.0   6.3
# 6                                  NaN  2003.0  10.0  31.0   1.0   6.0  28.2
# 7                                  NaN  2004.0   9.0   5.0  10.0   7.0   7.8
# 8                                  NaN  2004.0   9.0   5.0  14.0  57.0  18.6
# 9                                  NaN  2004.0  11.0  28.0  18.0  32.0  14.1
# 10                                 NaN  2005.0   1.0  19.0   6.0  11.0  36.4
# 11                                 NaN  2005.0   8.0  16.0   2.0  46.0  28.4
# 12                                 NaN  2005.0  11.0  14.0  21.0  38.0  51.4
# 13                                 NaN  2006.0   1.0   1.0   7.0  11.0  57.0
# 14                                 NaN  2006.0  10.0  23.0  21.0  17.0  19.0
# 15                                 NaN  2007.0   3.0  25.0   0.0  41.0  57.8
# 16                                 NaN  2007.0   7.0  16.0   1.0  13.0  22.0
# 17                                 NaN  2008.0   6.0  13.0  23.0  43.0  45.3
# 18                                 NaN  2008.0   7.0  19.0   2.0  39.0  28.7
# 19                                 NaN  2008.0   9.0  11.0   0.0  20.0  50.9
# 20                                 NaN  2009.0   8.0  10.0  20.0   7.0   9.1
# 21                                 NaN  2010.0   2.0  26.0  20.0  31.0  26.9
# 22                                 NaN  2010.0  12.0  21.0  17.0  19.0  40.6
# 23                                 NaN  2011.0   3.0   9.0   2.0  45.0  20.0
# 24                                 NaN  2011.0   3.0   9.0  21.0  24.0   1.0
# 25                                 NaN  2011.0   3.0  11.0   5.0  46.0  24.1
# 26                                 NaN  2011.0   4.0   7.0  14.0  32.0  43.2
#
#     Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  ...  \
# 0                      NaN                 NaN                   NaN  ...
# 1                      4.0                 1.0                   6.1  ...
# 2                      4.0                 1.0                   6.1  ...
# 3                      4.0                 1.0                   6.5  ...
# 4                      3.0                 1.0                   6.4  ...
# 5                      4.0                 1.0                   8.3  ...
# 6                      4.0                 1.0                   7.0  ...
# 7                      4.0                 1.0                   7.2  ...
# 8                      4.0                 1.0                   7.4  ...
# 9                      4.0                 1.0                   7.0  ...
# 10                     4.0                 1.0                   6.6  ...
# 11                     4.0                 1.0                   7.2  ...
# 12                     4.0                 1.0                   7.0  ...
# 13                     3.0                 1.0                   5.6  ...
# 14                     4.0                 1.0                   6.4  ...
# 15                     4.0                 1.0                   6.7  ...
# 16                     4.0                 1.0                   6.6  ...
# 17                     4.0                 3.0                   6.9  ...
# 18                     4.0                 1.0                   6.9  ...
# 19                     4.0                 1.0                   6.8  ...
# 20                     4.0                 1.0                   6.4  ...
# 21                     3.0                 1.0                   7.0  ...
# 22                     4.0                 1.0                   7.4  ...
# 23                     4.0                 1.0                   7.3  ...
# 24                     4.0                 1.0                   6.3  ...
# 25                     4.0                 1.0                   9.1  ...
# 26                     4.0                 1.0                   7.1  ...
#
#     Total Missing  Total Missing Description  Total Injuries  \
# 0             NaN                        NaN             NaN
# 1             NaN                        NaN             NaN
# 2             NaN                        NaN            10.0
# 3             NaN                        NaN             1.0
# 4             NaN                        NaN             NaN
# 5             NaN                        NaN           849.0
# 6             NaN                        NaN             NaN
# 7             NaN                        NaN             4.0
# 8             NaN                        NaN            40.0
# 9             NaN                        NaN            24.0
# 10            NaN                        NaN             NaN
# 11            NaN                        NaN            56.0
# 12            NaN                        NaN             NaN
# 13            NaN                        NaN             NaN
# 14            NaN                        NaN             NaN
# 15            NaN                        NaN           359.0
# 16            NaN                        NaN          2346.0
# 17            NaN                        NaN           357.0
# 18            NaN                        NaN             NaN
# 19            NaN                        NaN            77.0
# 20            NaN                        NaN           123.0
# 21            NaN                        NaN             NaN
# 22            NaN                        NaN             NaN
# 23            NaN                        NaN             NaN
# 24            NaN                        NaN             NaN
# 25            NaN                        NaN          6167.0
# 26            NaN                        NaN           132.0
#
#    Total Injuries Description Total Damage ($Mil)  Total Damage Description  \
# 0                         NaN                 NaN                       NaN
# 1                         3.0                 NaN                       1.0
# 2                         1.0                 NaN                       1.0
# 3                         1.0                 NaN                       1.0
# 4                         NaN                 NaN                       NaN
# 5                         3.0                90.0                       4.0
# 6                         NaN                 NaN                       NaN
# 7                         1.0                 NaN                       1.0
# 8                         1.0                 NaN                       1.0
# 9                         1.0                 NaN                       2.0
# 10                        NaN                 NaN                       NaN
# 11                        2.0                 NaN                       1.0
# 12                        NaN                 NaN                       NaN
# 13                        NaN                 NaN                       NaN
# 14                        NaN                 NaN                       NaN
# 15                        3.0                 NaN                       3.0
# 16                        4.0             12500.0                       4.0
# 17                        3.0                 NaN                       3.0
# 18                        NaN                 NaN                       NaN
# 19                        2.0                 NaN                       3.0
# 20                        3.0                 NaN                       3.0
# 21                        NaN                 NaN                       NaN
# 22                        NaN                 NaN                       NaN
# 23                        NaN                 NaN                       NaN
# 24                        NaN                 NaN                       NaN
# 25                        4.0            220136.6                       4.0
# 26                        3.0                 NaN                       1.0
#
#     Total Houses Destroyed  Total Houses Destroyed Description  \
# 0                      NaN                                 NaN
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                                 NaN
# 4                      NaN                                 NaN
# 5                      NaN                                 NaN
# 6                      NaN                                 NaN
# 7                      NaN                                 NaN
# 8                      NaN                                 NaN
# 9                      NaN                                 NaN
# 10                     NaN                                 NaN
# 11                     1.0                                 1.0
# 12                     NaN                                 NaN
# 13                     NaN                                 NaN
# 14                     NaN                                 NaN
# 15                 13556.0                                 4.0
# 16                  1331.0                                 4.0
# 17                     NaN                                 NaN
# 18                     NaN                                 NaN
# 19                     NaN                                 NaN
# 20                  5192.0                                 4.0
# 21                     NaN                                 NaN
# 22                     NaN                                 NaN
# 23                     NaN                                 NaN
# 24                     NaN                                 NaN
# 25                123661.0                                 4.0
# 26                     NaN                                 NaN
#
#     Total Houses Damaged  Total Houses Damaged Description
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                   20.0                               1.0
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# 5                    NaN                               NaN
# 6                    NaN                               NaN
# 7                    NaN                               NaN
# 8                    NaN                               NaN
# 9                    NaN                               1.0
# 10                   NaN                               NaN
# 11                   NaN                               NaN
# 12                   NaN                               NaN
# 13                   NaN                               NaN
# 14                   NaN                               NaN
# 15                   NaN                               NaN
# 16               43343.0                               4.0
# 17                 614.0                               3.0
# 18                   NaN                               NaN
# 19                1000.0                               3.0
# 20                   NaN                               NaN
# 21                   NaN                               NaN
# 22                   NaN                               NaN
# 23                   NaN                               NaN
# 24                   NaN                               NaN
# 25              280920.0                               4.0
# 26                   NaN                               NaN
#
# [27 rows x 46 columns]

# %% [markdown]
# # Dataset details
# 01/01/2000 to 15/05/2026

# %%
#tsunami dataset details
print("Dataset shape:", df.shape)
print("Columns:", df.columns)
print("Missing values:\n", df.isnull().sum())
# Out:
# Dataset shape: (57, 46)
# Columns: Index(['Search Parameters', 'Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec',
#        'Tsunami Event Validity', 'Tsunami Cause Code', 'Earthquake Magnitude',
#        'Vol', 'More Info', 'Deposits', 'Country', 'Location Name', 'Latitude',
#        'Longitude', 'Maximum Water Height (m)', 'Number of Runups',
#        'Tsunami Magnitude (Abe)', 'Tsunami Magnitude (Iida)',
#        'Tsunami Intensity', 'Deaths', 'Death Description', 'Missing',
#        'Missing Description', 'Injuries', 'Injuries Description',
#        'Damage ($Mil)', 'Damage Description', 'Houses Destroyed',
#        'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='str')
# Missing values:
#  Search Parameters                     56
# Year                                   1
# Mo                                     1
# Dy                                     1
# Hr                                     4
# Mn                                     4
# Sec                                    4
# Tsunami Event Validity                 1
# Tsunami Cause Code                     1
# Earthquake Magnitude                   3
# Vol                                   52
# More Info                             57
# Deposits                               1
# Country                                1
# Location Name                          1
# Latitude                               3
# Longitude                              3
# Maximum Water Height (m)               6
# Number of Runups                       1
# Tsunami Magnitude (Abe)               57
# Tsunami Magnitude (Iida)              57
# Tsunami Intensity                     57
# Deaths                                54
# Death Description                     54
# Missing                               57
# Missing Description                   57
# Injuries                              56
# Injuries Description                  56
# Damage ($Mil)                         56
# Damage Description                    51
# Houses Destroyed                      56
# Houses Destroyed Description          55
# Houses Damaged                        56
# Houses Damaged Description            55
# Total Deaths                          44
# Total Death Description               43
# Total Missing                         56
# Total Missing Description             56
# Total Injuries                        33
# Total Injuries Description            30
# Total Damage ($Mil)                   51
# Total Damage Description              31
# Total Houses Destroyed                46
# Total Houses Destroyed Description    46
# Total Houses Damaged                  45
# Total Houses Damaged Description      44
# dtype: int64

# %% [markdown]
# # Tsunami location map

# %%
# tsunami locations using folium
#center the map on the average location of the tsunamis

avg_lat = df['Latitude'].mean()
avg_lon = df['Longitude'].mean()
m = folium.Map(location=[avg_lat, avg_lon], zoom_start=5)
for _, row in df.iterrows():
    if pd.notnull(row['Latitude']) and pd.notnull(row['Longitude']):
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=5,
            color='red',
            fill=True,
            fill_color='red'
        ).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77815564e9f3ed19a14637ece765d054 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77815564e9f3ed19a14637ece765d054&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77815564e9f3ed19a14637ece765d054 = L.map(
#                 &quot;map_77815564e9f3ed19a14637ece765d054&quot;,
#                 {
#                     center: [35.3519074074074, 140.16666666666666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4425ece5c08ab51221d20dd84be4e29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4425ece5c08ab51221d20dd84be4e29.addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_b2771c71691c808f678a80e976f4b8bc = L.circleMarker(
#                 [34.221, 139.131],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_ad9bc7358094de4330c2ff1e1cee8d3d = L.circleMarker(
#                 [34.319, 139.26],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_f4c27e57f847a6c7ff705be76c2aea9e = L.circleMarker(
#                 [33.901, 139.376],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_ca7e4ff0fc4c575e6b4258c290966fff = L.circleMarker(
#                 [23.346, 124.09],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_9d9de0d133b1d252a89fa67c51156552 = L.circleMarker(
#                 [41.815, 143.91],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_77815564e9f3ed19a14637ece765d054);
#
#
#             var circle_marker_f6ec3839cdda1d7ae9ba88ee4ebe8e7c = L.circleMarker(
#                 [37.812, 142.619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# # One tsunami detail

# %%
#show details on the ONE biggest tsunamis using "Maximum Water Height (m)"

top_tsunamis = df.sort_values(by='Maximum Water Height (m)', ascending=False).head(1)
print(top_tsunamis)
# Out:
#    Search Parameters    Year   Mo    Dy   Hr    Mn   Sec  \
# 25               NaN  2011.0  3.0  11.0  5.0  46.0  24.1
#
#     Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  ...  \
# 25                     4.0                 1.0                   9.1  ...
#
#     Total Missing  Total Missing Description  Total Injuries  \
# 25            NaN                        NaN          6167.0
#
#    Total Injuries Description Total Damage ($Mil)  Total Damage Description  \
# 25                        4.0            220136.6                       4.0
#
#     Total Houses Destroyed  Total Houses Destroyed Description  \
# 25                123661.0                                 4.0
#
#     Total Houses Damaged  Total Houses Damaged Description
# 25              280920.0                               4.0
#
# [1 rows x 46 columns]
